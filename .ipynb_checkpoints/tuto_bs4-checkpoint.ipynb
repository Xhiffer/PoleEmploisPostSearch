# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
#if page start with 2 good if 4/5 bad in general
page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")


soup = BeautifulSoup(page.content, 'html.parser')




html = list(soup.children)[2]
#print(list(soup.children))
body = list(html.children)[3]

p = list(body.children)[1]
#take first i guess
#p.get_text()


#find all text
soup = BeautifulSoup(page.content, 'html.parser')
#soup.find_all('p')
#take first of the list
#soup.find_all('p')[0].get_text()
#mydivs = soup.find_all("div", {"class": "stylelistrow"})

#search by class
page = requests.get("http://dataquestio.github.io/web-scraping-pages/ids_and_classes.html")
soup = BeautifulSoup(page.content, 'html.parser')
#soup.find_all('p', class_='outer-text')
#soup.find_all(id="first")
#soup.select("div p")
#//////////////////////////////////////////////////////////////////////////////

page = requests.get("http://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]
#print(tonight.prettify())

period = tonight.find(class_="period-name").get_text()
short_desc = tonight.find(class_="short-desc").get_text()
temp = tonight.find(class_="temp").get_text()
#print(period)
#print(short_desc)
#print(temp)


img = tonight.find("img")
desc = img['title']
#print(desc)




period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]

short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]
#print(short_descs)
#print(temps)
#print(descs)




weather = pd.DataFrame({
    "period": periods,
    "short_desc": short_descs,
    "temp": temps,
    "desc":descs
})
display(weather)
# Out:
#           period                      short_desc         temp  \
# 0      Overnight                     Rain Likely   Low: 50 °F
# 1         Friday  ShowersLikely thenPartly Sunny  High: 58 °F
# 2    FridayNight                   ChanceShowers   Low: 48 °F
# 3       Saturday                           Sunny  High: 59 °F
# 4  SaturdayNight                    Mostly Clear   Low: 46 °F
# 5         Sunday                           Sunny  High: 62 °F
# 6    SundayNight                    Mostly Clear   Low: 47 °F
# 7         Monday                           Sunny  High: 66 °F
# 8    MondayNight                    Mostly Clear   Low: 48 °F
#
#                                                 desc
# 0  Overnight: Rain likely.  Cloudy, with a low ar...
# 1  Friday: Showers likely before 10am.  Cloudy, t...
# 2  Friday Night: A 40 percent chance of showers a...
# 3  Saturday: Sunny, with a high near 59. West nor...
# 4  Saturday Night: Mostly clear, with a low aroun...
# 5                Sunday: Sunny, with a high near 62.
# 6  Sunday Night: Mostly clear, with a low around 47.
# 7                Monday: Sunny, with a high near 66.
# 8  Monday Night: Mostly clear, with a low around 48.
